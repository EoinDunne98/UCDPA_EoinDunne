# %%
import pandas as pd
fifa = pd.read_csv('fifa_23_280922.csv')

fifa
# Out:
#                   Nom  Général  Potentiel  Performance                 Pays  \
# 0           K. Mbappé       91         95         93.0               France
# 1      R. Lewandowski       91         91         91.0               Poland
# 2          K. Benzema       91         91         91.0               France
# 3            L. Messi       91         91         91.0            Argentina
# 4        K. De Bruyne       91         91         91.0              Belgium
# ...               ...      ...        ...          ...                  ...
# 18441       Huo Liang       49         49         49.0             China PR
# 18442      Zhou Zheng       46         51         48.5             China PR
# 18443        N. Rabha       47         50         48.5                India
# 18444        Ning Hao       48         48         48.0             China PR
# 18445        D. Duffy       35         49         42.0  Republic of Ireland
#
# ...

# %%
fifa.duplicated().sum()
# Out:
# 0

# %%
fifa.describe()
# Out:
#             Général     Potentiel   Performance  Mauvais pied  \
# count  18446.000000  18446.000000  18446.000000  18446.000000
# mean      65.760273     70.942589     68.351431      2.944216
# std        6.790877      6.184479      5.908524      0.672973
# min       35.000000     48.000000     42.000000      1.000000
# 25%       62.000000     67.000000     64.500000      3.000000
# 50%       66.000000     71.000000     68.000000      3.000000
# 75%       70.000000     75.000000     72.000000      3.000000
# max       91.000000     95.000000     93.000000      5.000000
#
#        Gestes techniques        Taille             Id       Centres  \
# count       18446.000000  18446.000000   18446.000000  18446.000000
# mean            2.362789    181.549821  237020.339803     49.388431
# std             0.770640      6.855294   26780.215193     17.873496
# min             1.000000    155.000000    1179.000000      6.000000
# ...

# %%
fifa.Général.hist();

# %%
fifa.head()
# Out:
#               Nom  Général  Potentiel  Performance       Pays  \
# 0       K. Mbappé       91         95         93.0     France
# 1  R. Lewandowski       91         91         91.0     Poland
# 2      K. Benzema       91         91         91.0     France
# 3        L. Messi       91         91         91.0  Argentina
# 4    K. De Bruyne       91         91         91.0    Belgium
#
#                   Club Bon pied  Mauvais pied  Gestes techniques  Taille  ...  \
# 0  Paris Saint-Germain    Right             4                  5     182  ...
# 1         FC Barcelona    Right             4                  4     185  ...
# 2       Real Madrid CF    Right             4                  4     185  ...
# 3  Paris Saint-Germain     Left             4                  4     169  ...
# 4      Manchester City    Right             5                  4     181  ...
#
#   Penalty Calme Conscience defensive Tacle debout  Tacle glisse  Plongeon  \
# ...

# %%
fifa.tail(10)
# Out:
#                 Nom  Général  Potentiel  Performance                 Pays  \
# 18436   Wang Hanlin       50         50         50.0             China PR
# 18437      N. Logue       46         54         50.0  Republic of Ireland
# 18438     Guo Yunqi       48         51         49.5             China PR
# 18439      He Youzu       47         52         49.5             China PR
# 18440  S. Abdusalam       49         49         49.0             China PR
# 18441     Huo Liang       49         49         49.0             China PR
# 18442    Zhou Zheng       46         51         48.5             China PR
# 18443      N. Rabha       47         50         48.5                India
# 18444      Ning Hao       48         48         48.0             China PR
# 18445      D. Duffy       35         49         42.0  Republic of Ireland
#
#                                     Club Bon pied  Mauvais pied  \
# 18436             Chengdu Rongcheng F.C.    Right             3
# ...

# %%
fifa[0:5][['Nom','Général']]
# Out:
#               Nom  Général
# 0       K. Mbappé       91
# 1  R. Lewandowski       91
# 2      K. Benzema       91
# 3        L. Messi       91
# 4    K. De Bruyne       91

# %%
fifa.iloc[[1,10,100, 1000], [0,1,2,3,8]]
# Out:
#                  Nom  Général  Potentiel  Performance  Gestes techniques
# 1     R. Lewandowski       91         91         91.0                  4
# 10          M. Neuer       90         90         90.0                  1
# 100     Carlos Soler       83         88         85.5                  3
# 1000      N. Collins       75         82         78.5                  2

# %%
fifa[fifa['Potentiel']>=90]
# Out:
#                      Nom  Général  Potentiel  Performance         Pays  \
# 0              K. Mbappé       91         95         93.0       France
# 1         R. Lewandowski       91         91         91.0       Poland
# 2             K. Benzema       91         91         91.0       France
# 3               L. Messi       91         91         91.0    Argentina
# 4           K. De Bruyne       91         91         91.0      Belgium
# 5             E. Haaland       88         94         91.0       Norway
# 6            T. Courtois       90         91         90.5      Belgium
# 7               J. Oblak       89         91         90.0     Slovenia
# 8               M. Salah       90         90         90.0        Egypt
# 9            V. van Dijk       90         90         90.0  Netherlands
# 10              M. Neuer       90         90         90.0      Germany
# 11     Cristiano Ronaldo       90         90         90.0     Portugal
# ...

# %%
fifa[(fifa['Potentiel']>=90) & (fifa['Pays']=='England')]
# Out:
#                     Nom  Général  Potentiel  Performance     Pays  \
# 26  T. Alexander-Arnold       87         90         88.5  England
# 28             P. Foden       85         92         88.5  England
# 42        J. Bellingham       84         91         87.5  England
# 61            F. Tomori       84         90         87.0  England
#
#                  Club Bon pied  Mauvais pied  Gestes techniques  Taille  ...  \
# 26          Liverpool    Right             4                  3     180  ...
# 28    Manchester City     Left             3                  4     171  ...
# 42  Borussia Dortmund    Right             4                  4     186  ...
# 61           AC Milan    Right             4                  2     185  ...
#
#    Penalty Calme Conscience defensive Tacle debout  Tacle glisse  Plongeon  \
# 26      55    82                   79           83            80        14
# 28      64    84                   58           59            47         8
# ...

# %%
fifa[(fifa['Potentiel']>=90) & (fifa['Pays']=='France')]
# Out:
#              Nom  Général  Potentiel  Performance    Pays  \
# 0      K. Mbappé       91         95         93.0  France
# 2     K. Benzema       91         91         91.0  France
# 29    M. Maignan       87         90         88.5  France
# 45  T. Hernández       85         90         87.5  France
#
#                    Club Bon pied  Mauvais pied  Gestes techniques  Taille  \
# 0   Paris Saint-Germain    Right             4                  5     182
# 2        Real Madrid CF    Right             4                  4     185
# 29             AC Milan    Right             4                  1     191
# 45             AC Milan     Left             3                  3     184
#
#     ... Penalty Calme Conscience defensive Tacle debout  Tacle glisse  \
# 0   ...      80    88                   26           34            32
# 2   ...      84    90                   43           24            18
# 29  ...      15    66                   23           16            19
# ...

# %%
fifa[(fifa['Potentiel']>=80) & (fifa['Pays']=='Republic of Ireland')]
# Out:
#                  Nom  Général  Potentiel  Performance                 Pays  \
# 1000      N. Collins       75         82         78.5  Republic of Ireland
# 1230       G. Bazunu       70         85         77.5  Republic of Ireland
# 1533     C. Kelleher       73         80         76.5  Republic of Ireland
# 1612      M. Travers       73         80         76.5  Republic of Ireland
# 1747  A. Omobamidele       70         82         76.0  Republic of Ireland
# 3351      T. Parrott       66         80         73.0  Republic of Ireland
# 5001        D. Devoy       63         80         71.5  Republic of Ireland
# 6532       A. Murphy       60         80         70.0  Republic of Ireland
# 7508     E. Ferguson       59         80         69.5  Republic of Ireland
#
#                          Club Bon pied  Mauvais pied  Gestes techniques  \
# 1000  Wolverhampton Wanderers    Right             3                  2
# 1230              Southampton    Right             2                  1
# ...

# %%
fifa[(fifa['Général']>=70) & (fifa['Pays']=='Republic of Ireland')]
# Out:
#                  Nom  Général  Potentiel  Performance                 Pays  \
# 1000      N. Collins       75         82         78.5  Republic of Ireland
# 1230       G. Bazunu       70         85         77.5  Republic of Ireland
# 1508      M. Doherty       77         77         77.0  Republic of Ireland
# 1533     C. Kelleher       73         80         76.5  Republic of Ireland
# 1584       J. Cullen       75         78         76.5  Republic of Ireland
# 1612      M. Travers       73         80         76.5  Republic of Ireland
# 1747  A. Omobamidele       70         82         76.0  Republic of Ireland
# 1784      S. Coleman       76         76         76.0  Republic of Ireland
# 2493       D. O'Shea       71         78         74.5  Republic of Ireland
# 2830         J. Egan       74         74         74.0  Republic of Ireland
# 2876      D. Lenihan       73         75         74.0  Republic of Ireland
# ...

# %%
fifa[:]
# Out:
#                   Nom  Général  Potentiel  Performance                 Pays  \
# 0           K. Mbappé       91         95         93.0               France
# 1      R. Lewandowski       91         91         91.0               Poland
# 2          K. Benzema       91         91         91.0               France
# 3            L. Messi       91         91         91.0            Argentina
# 4        K. De Bruyne       91         91         91.0              Belgium
# ...               ...      ...        ...          ...                  ...
# 18441       Huo Liang       49         49         49.0             China PR
# 18442      Zhou Zheng       46         51         48.5             China PR
# 18443        N. Rabha       47         50         48.5                India
# 18444        Ning Hao       48         48         48.0             China PR
# 18445        D. Duffy       35         49         42.0  Republic of Ireland
#
# ...

# %%
fifa[12356:12358]
# Out:
#             Nom  Général  Potentiel  Performance     Pays            Club  \
# 12356   L. Reed       65         67         66.0  England    Swindon Town
# 12357  M. Silva       66         66         66.0  Uruguay  Real Salt Lake
#
#       Bon pied  Mauvais pied  Gestes techniques  Taille  ... Penalty Calme  \
# 12356    Right             3                  3     173  ...      54    63
# 12357    Right             3                  2     185  ...      49    55
#
#       Conscience defensive Tacle debout  Tacle glisse  Plongeon  Jeu main  \
# 12356                   60           63            62         9         7
# 12357                   63           64            60         6        12
#
#        Jeu pied  Placement.1  Reflexes
# 12356        10           12        12
# 12357         7            6        14
#
# [2 rows x 49 columns]

# %%
fifa['Performance'].plot()
# Out:
# <AxesSubplot:>

# %%
fifa['Général'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
